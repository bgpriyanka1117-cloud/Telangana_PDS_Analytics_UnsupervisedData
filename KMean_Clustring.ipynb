# %%
import pandas as pd

# %%
pca_df = pd.read_csv("../data/Master_data/pca_data.csv")
pca_df
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      -1.883081 -1.657850 -0.667426  1.209770  0.200160  2.423177 -0.408070
# 1      -1.702748 -1.162848 -0.535037  0.912080  0.191925  2.243356 -0.311496
# 2      -1.760839 -1.416728 -0.670481  1.113658  0.315450  2.469945 -0.404734
# 3      -1.679315 -1.080482 -0.407049  0.979341  0.080585  3.400451 -0.688134
# 4      -1.393210 -0.584055 -0.466927  0.782557  0.395367  3.443759 -0.703478
# ...          ...       ...       ...       ...       ...       ...       ...
# 482112 -2.537074 -2.620700 -0.043336  0.340336  0.035164  3.596796 -3.344375
# 482113 -2.290027 -2.535997 -0.269793  0.412294  0.479926  4.310948 -3.737624
# 482114 -2.782455 -3.284147 -0.449152  1.367991 -0.129816  3.943616 -3.449342
# 482115 -2.080059 -1.834851 -0.145728  0.483740  0.163219  4.124446 -3.501917
# 482116 -2.344873 -2.282015 -0.037585  0.603777 -0.151864  4.154296 -3.523424
#
# ...

# %%
pca_df.shape
# Out:
# (482117, 20)

# %%
#To find K points
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

K = range(2, 11)

for k in K:
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )
    kmeans.fit(pca_df)
    wcss.append(kmeans.inertia_)

# Plot
plt.figure(figsize=(8,5))
plt.plot(K, wcss, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.grid(True)
plt.show()

# %%
#Kmean into cluster
from sklearn.cluster import KMeans

kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10
)

clusters = kmeans.fit_predict(pca_df)

pca_df['Cluster'] = clusters

# %%
pca_df['Cluster'].head(20)
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    2
# 19    2
# Name: Cluster, dtype: int32

# %%
pca_df.tail()
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 482112 -2.537074 -2.620700 -0.043336  0.340336  0.035164  3.596796 -3.344375
# 482113 -2.290027 -2.535997 -0.269793  0.412294  0.479926  4.310948 -3.737624
# 482114 -2.782455 -3.284147 -0.449152  1.367991 -0.129816  3.943616 -3.449342
# 482115 -2.080059 -1.834851 -0.145728  0.483740  0.163219  4.124446 -3.501917
# 482116 -2.344873 -2.282015 -0.037585  0.603777 -0.151864  4.154296 -3.523424
#
#              PC8       PC9      PC10  ...      PC12      PC13      PC14  \
# 482112  0.621790 -1.997668  1.540401  ...  0.998751 -1.130262 -0.835363
# 482113  0.675464 -3.136498  2.209348  ...  1.147411 -0.657185  1.930130
# 482114  1.247681 -3.361279  3.328315  ...  1.409768  0.092324  3.795696
# 482115  0.854728 -0.764497  2.317891  ...  0.811090 -1.281530 -1.485283
# 482116  0.691226 -1.098262  1.803566  ...  0.870266 -1.184757 -0.865886
#
# ...

# %%
pca_df['Cluster'].value_counts()
# Out:
# Cluster
# 2    224984
# 1    189387
# 0     35992
# 3     31754
# Name: count, dtype: int64

# %% [markdown]
# | Cluster | Count   |
# | ------- | ------- |
# | 2       | 224,984 |
# | 1       | 189,387 |
# | 0       | 35,992  |
# | 3       | 31,754  |

# %% [markdown]
# Cluster Distribution Summary (Total: 482,117 rows)
#
# data in 4 clusters bane hain:
#
# Data is divided into 4 clusters:
#
# Cluster 2 → Largest group (~46.67%)
# Cluster 1 → Second largest (~39.28%)
# Cluster 0 → Smaller segment (~7.47%)
# Cluster 3 → Smaller segment (~6.59%)

# %% [markdown]
# Final Interpretation (Report Format)
#
# The dataset of 482,117 rows is grouped into four clusters based on behavioral similarity:
#
# Cluster 2 represents the largest segment (~46.7%), indicating the most dominant behavior pattern in the dataset.
#
# Cluster 1 is the second largest group (~39.3%), also forming a major portion of the population.
#
# Cluster 0 accounts for about 7.5%, representing a smaller but noticeable subgroup with distinct characteristics.
#
# Cluster 3 is the smallest cluster (~6.6%), likely capturing rare or unusual patterns in the data.

# %%
import matplotlib.pyplot as plt

# Heavy data hai, sample le lo
sample_plot = pca_df.sample(
    20000,
    random_state=42
)

plt.figure(figsize=(10,7))

scatter = plt.scatter(
    sample_plot['PC1'],
    sample_plot['PC2'],
    c=sample_plot['Cluster'],
    alpha=0.5
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("KMeans Clusters (PC1 vs PC2)")

plt.colorbar(label="Cluster")
plt.show()

# %%
import matplotlib.pyplot as plt

# Cluster counts
cluster_counts = pca_df["Cluster"].value_counts().sort_index()

plt.figure(figsize=(7,7))

plt.pie(
    cluster_counts,
    labels=cluster_counts.index,
    autopct='%1.1f%%',
    startangle=140
)

plt.title("Cluster Distribution (Pie Chart)")
plt.show()

#Pie chart = shows percentage split

# %%
plt.figure(figsize=(7,7))

plt.pie(
    cluster_counts,
    labels=[f"Cluster {i}" for i in cluster_counts.index],
    autopct='%1.1f%%',
    startangle=140,
    shadow=True
)

plt.title("KMeans Cluster Distribution")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Sample data
sample_df = pca_df.sample(n=50000, random_state=42)

# Use only PCA features (important)
X = sample_df[['PC1', 'PC2']]

scores = []

for k in range(2, 11):

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X)

    score = silhouette_score(X, labels)

    scores.append(score)

    print(f"K={k}, Silhouette Score={score:.4f}")
# Out:
# K=2, Silhouette Score=0.7519
# K=3, Silhouette Score=0.4822
# K=4, Silhouette Score=0.4558
# K=5, Silhouette Score=0.4246
# K=6, Silhouette Score=0.4173
# K=7, Silhouette Score=0.4318
# K=8, Silhouette Score=0.3704
# K=9, Silhouette Score=0.3894
# K=10, Silhouette Score=0.3717

# %%
KMeans(n_clusters=2)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# | K  | Silhouette Score    |
# | -- | ------------------- |
# | 2  | **0.7519** ⭐ (best) |
# | 3  | 0.4822              |
# | 4  | 0.4558              |
# | 5  | 0.4246              |
# | 6  | 0.4173              |
# | 7  | 0.4318              |
# | 8  | 0.3704              |
# | 9  | 0.3894              |
# | 10 | 0.3717              |

# %%
#for Highest value Evaltuition 
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(
    range(2,11),
    scores,
    marker='o'
)

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis")
plt.grid(True)

plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score

# Sample data
sample_df = pca_df.sample(
    n=50000,
    random_state=42
)

db_scores = []

for k in range(2, 11):

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(
        sample_df
    )

    db = davies_bouldin_score(
        sample_df,
        labels
    )

    db_scores.append(db)

    print(
        f"K={k}, Davies-Bouldin Score={db:.4f}"
    )
# Out:
# K=2, Davies-Bouldin Score=0.8514
# K=3, Davies-Bouldin Score=1.7804
# K=4, Davies-Bouldin Score=1.6192
# K=5, Davies-Bouldin Score=1.8345
# K=6, Davies-Bouldin Score=1.7507
# K=7, Davies-Bouldin Score=1.7345
# K=8, Davies-Bouldin Score=1.8214
# K=9, Davies-Bouldin Score=1.7532
# K=10, Davies-Bouldin Score=1.6517

# %%
#for Lowest value best Evalutions
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(
    range(2,11),
    db_scores,
    marker='o'
)

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Davies-Bouldin Score")
plt.title("Davies-Bouldin Score vs K")
plt.grid(True)

plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score

# Sample data
sample_df = pca_df.sample(
    n=50000,
    random_state=42
)

ch_scores = []

for k in range(2, 11):

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(
        sample_df
    )

    ch = calinski_harabasz_score(
        sample_df,
        labels
    )

    ch_scores.append(ch)

    print(
        f"K={k}, Calinski-Harabasz Score={ch:.2f}"
    )
# Out:
# K=2, Calinski-Harabasz Score=17859.28
# K=3, Calinski-Harabasz Score=14083.61
# K=4, Calinski-Harabasz Score=12135.20
# K=5, Calinski-Harabasz Score=10482.42
# K=6, Calinski-Harabasz Score=9272.13
# K=7, Calinski-Harabasz Score=8393.86
# K=8, Calinski-Harabasz Score=7704.21
# K=9, Calinski-Harabasz Score=7141.81
# K=10, Calinski-Harabasz Score=6728.17

# %%
# Highest value best Evalution
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(
    range(2,11),
    ch_scores,
    marker='o'
)

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Calinski-Harabasz Score")
plt.title("Calinski-Harabasz Score vs K")
plt.grid(True)

plt.show()

# %%
print(pca_df.shape)
# Out:
# (482117, 21)

# %%
#save Kmean ,Clustring,Clustring_EvalutingFile
pca_df.to_csv("../data/KmeanClustring_And_Evalution_data.csv", index=False)
